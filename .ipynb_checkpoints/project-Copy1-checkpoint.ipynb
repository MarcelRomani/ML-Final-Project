# %%
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor, ExtraTreesClassifier, RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from collections import Counter

# %% [markdown]
# # Loading and pre-processing the data

# %%
# Loading the datasets
test_data = read_csv("ValidationData.csv", header=0, delimiter=',')
train_data = read_csv("TrainingData.csv", header=0, delimiter=',')

# %%
# Drop attributes we are not gonna use        
test_data.drop(['SPACEID','RELATIVEPOSITION','USERID','PHONEID','TIMESTAMP'], axis=1, inplace=True)
train_data.drop(['SPACEID','RELATIVEPOSITION','USERID','PHONEID','TIMESTAMP'], axis=1, inplace=True)

# Drop attributes that remain constant in either set because they will not carry any information
for col in train_data.columns:
    if (len(train_data[col].unique()) == 1 or len(test_data[col].unique()) == 1):
        test_data.drop([col], axis=1, inplace=True)
        train_data.drop([col], axis=1, inplace=True)

# %%
# Looking for missing values
print("Train data missing values:", train_data.isnull().values.any())
print("Test data missing values:", test_data.isnull().values.any())
# Out:
# Train data missing values: False
# Test data missing values: False

# %%
#-105dB would actually mean 10**(-8.5)% or ~0.000000003% of intensity so it 
#is safe to assume -105dB = 0 = No Intensity

test_data.replace({100:-100}, inplace=True)
test_data.iloc[:,0:312].clip(-100,0,inplace=True)
train_data.replace({100:-100}, inplace=True)
train_data.iloc[:,0:312].clip(-100,0,inplace=True)

# %%
#train_data["FLOOR"].replace({1: "1", 2: "2", 0 : "0", 3 : "3", 4 : "4"}, inplace=True)
#test_data["FLOOR"].replace({1: "1", 2: "2", 0 : "0", 3 : "3", 4 : "4"}, inplace=True)
#
#test_data["BUILDINGID"].replace({1: "1", 2: "2", 0 : "0"}, inplace=True)
#train_data["BUILDINGID"].replace({1: "1", 2: "2", 0 : "0"}, inplace=True)

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (19937, 316)
# (1111, 316)

# %%
plt.figure(1)
sn.countplot(x="BUILDINGID", data=train_data)
plt.savefig('figura1.eps', format='eps')

plt.figure(2)
sn.countplot(x="BUILDINGID",hue="FLOOR", data=train_data)
plt.savefig('figura2.eps', format='eps')

plt.figure(3)
ax = sn.scatterplot(x="LONGITUDE", y="LATITUDE", data=train_data[train_data.BUILDINGID==0])
sn.scatterplot(x="LONGITUDE", y="LATITUDE", data=train_data[train_data.BUILDINGID==1], ax=ax)
sn.scatterplot(x="LONGITUDE", y="LATITUDE", data=train_data[train_data.BUILDINGID==2], ax=ax)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Let's start testing some methods...

# %%
#Separate into x,y
X_train   = train_data.iloc[:,0:312]
Lon_train = train_data.iloc[:,312]
Lat_train = train_data.iloc[:,313]
Flo_train = train_data.iloc[:,314]
Bui_train = train_data.iloc[:,315]

X_test   = test_data.iloc[:,0:312]
Lon_test = test_data.iloc[:,312]
Lat_test = test_data.iloc[:,313]
Flo_test = test_data.iloc[:,314]
Bui_test = test_data.iloc[:,315]

# %% [markdown]
# ### PCA before clustering

# %%
from sklearn.preprocessing import minmax_scale
pca = PCA();
# We scale the data to improve PCA performance. 
pca.fit(X_train);
components = np.sum(np.cumsum(pca.explained_variance_ratio_) <= 0.9)
print('If we maintain 90% of the variance we obtain {} components'.format(components))
pca = PCA(n_components=components);
X_train_pca = pca.fit_transform(X_train);
X_test_pca = pca.transform(X_test)
df = pd.DataFrame(X_train_pca)

print('Original shape:', X_train.shape,'New shape:',X_train_pca.shape)
# Out:
# If we maintain 90% of the variance we obtain 54 components
# Original shape: (19937, 312) New shape: (19937, 54)

# %%
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

kmeans = KMeans(n_clusters=3, random_state=123)
gauss = GaussianMixture(n_components=3,
                        covariance_type='diag',
                        random_state=123)
gauss_full = GaussianMixture(n_components=3,
                             covariance_type='full',
                             random_state=123)

df["label_kmeans"] = kmeans.fit_predict(X_train_pca)
df["label_gauss"] = gauss.fit_predict(X_train_pca)
df["label_gauss_full"] = gauss_full.fit_predict(X_train_pca)
df["building"] = Bui_train

# %%
fig, axes = plt.subplots(1,4,figsize=(16,4));
sn.scatterplot(x=0, y=1, data = df, hue='building', ax=axes[0], alpha=0.1)
sn.scatterplot(x=0, y=1, data = df, hue='label_kmeans', ax=axes[1], alpha=0.1)
sn.scatterplot(x=0, y=1, data = df, hue='label_gauss', ax=axes[2], alpha=0.1)
sn.scatterplot(x=0, y=1, data = df, hue='label_gauss_full', ax=axes[3], alpha=0.1)
plt.tight_layout();

# %%
from sklearn.metrics import calinski_harabasz_score, silhouette_score, davies_bouldin_score
index= pd.MultiIndex.from_arrays([[], []], names=('model', 'K'))

results_df3 = pd.DataFrame(index=index, columns= ['CH score', 'Silhouette score', 'DB score']);

for k in [2,3,4,5,6,7,8,9]:
    kmeans = KMeans(n_clusters=k,
                    random_state=123);
    kmeans.fit(X_train_pca);

    CH = calinski_harabasz_score(X_train_pca, kmeans.labels_ );
    S = silhouette_score(X_train_pca, kmeans.labels_ );
    DB = davies_bouldin_score(X_train_pca, kmeans.labels_ );
    
    results_df3.loc[('kmeans', k),:] = [CH,S,DB];

# %%
results_df3
# Out:
#              CH score Silhouette score  DB score
# model  K
# kmeans 2  2131.402205         0.102021  2.891893
#        3  1987.899661         0.126053  2.529495
#        4  1998.794024         0.133435  2.046269
#        5   1946.91894         0.149896  1.998951
#        6  1777.014691         0.145208  1.873313
#        7  1837.092823          0.15285  1.854719
#        8  1910.614985          0.19138  1.730856
#        9  1817.911759         0.196042  1.674839

# %%
results_df3 = results_df3.sort_index()
results_df3 = results_df3.astype(float)

# %%
fig, ax = plt.subplots(1,3, figsize=(16,6))

sn.lineplot(x='K', y='CH score',data=results_df3.reset_index(),label='CH score', color='r', ax=ax[0]);
sn.lineplot(x='K', y='Silhouette score',data=results_df3.reset_index(),label='Silhouette',ax=ax[1]);
sn.lineplot(x='K', y='DB score',data=results_df3.reset_index(),label='DB', ax=ax[2]);

# %%
for k in [2, 3, 4, 5, 6, 7, 8, 9]:
    gm =GaussianMixture(n_components=k, 
                        covariance_type='full',
                        random_state=123)
    gm.fit(X_train_pca);
    prediction = gm.predict(X_train_pca) 
    CH = calinski_harabasz_score(X_train_pca,prediction )
    S = silhouette_score(X_train_pca, prediction)
    DB = davies_bouldin_score(X_train_pca,prediction)
    
    results_df3.loc[('GM_full', k),:] = [CH,S,DB]
    
for k in [2, 3, 4, 5, 6, 7, 8, 9]:
    gm =GaussianMixture(n_components=k, 
                        covariance_type='diag',
                        random_state=123)
    gm.fit(X_train_pca);
    prediction = gm.predict(X_train_pca) 
    CH = calinski_harabasz_score(X_train_pca,prediction )
    S = silhouette_score(X_train_pca, prediction)
    DB = davies_bouldin_score(X_train_pca,prediction)
    
    results_df3.loc[('GM_diag', k),:] = [CH,S,DB]
    
results_df3
# Out:
#               CH score  Silhouette score  DB score
# model   K
# kmeans  2  2131.402205          0.102021  2.891893
#         3  1987.899661          0.126053  2.529495
#         4  1998.794024          0.133435  2.046269
#         5  1946.918940          0.149896  1.998951
#         6  1777.014691          0.145208  1.873313
#         7  1837.092823          0.152850  1.854719
#         8  1910.614985          0.191380  1.730856
#         9  1817.911759          0.196042  1.674839
# GM_full 2  1943.892858          0.094938  3.063373
#         3  1403.385623          0.030587  2.910331
#         4  1252.338311          0.041258  2.914444
#         5  1314.984107          0.067344  2.680607
#         6  1290.028576          0.085695  2.422975
#         7  1540.743639          0.130175  2.239771
#         8  1305.776798          0.119764  2.377996
#         9  1192.959609          0.121707  2.567204
# GM_diag 2  2024.352363          0.096533  2.995201
#         3  1439.961834          0.023707  3.062762
#         4  1119.824531          0.014971  3.782140
#         5  1291.523470          0.049778  3.237130
#         6  1198.530244          0.061324  2.990138
#         7  1315.849489          0.102798  2.678684
#         8  1534.843428          0.093699  2.249559
#         9  1285.507984         -0.038375  2.633450

# %% [markdown]
# # Classification

# %%
def errorfunc(test,pred):
    error=0
    for i in range(len(test)):
        if (pred[i] != test[i]):
            error = error +abs(pred[i]-test[i])
    return error

def compute_classf_metrics(y, pred):
    return [accuracy_score(y, pred), f1_score(y, pred, average="macro"), errorfunc(y,pred)]

# %%
#This is just kinda floating here probs can move anywhere
Bui_results = pd.DataFrame(columns=['Accuracy', 'F1-score (macro avg)','Custom error score'])
Flo_results = pd.DataFrame(columns=['Accuracy', 'F1-score (macro avg)','Custom error score'])

# %% [markdown]
# ## BUILDING classification

# %% [markdown]
# ### Decision Tree Classifier

# %%
np.random.seed(11)
#Lets start with buildings
model_tree = DecisionTreeClassifier()

model_tree.fit(X_train, Bui_train)
Bui_pred_DT = model_tree.predict(X_test)
print(confusion_matrix(Bui_test, Bui_pred_DT, labels=[0, 1, 2]))
Bui_results.loc['DT',:] = compute_classf_metrics(Bui_test, Bui_pred_DT)
# Out:
# [[524   2  10]
#  [  3 289  15]
#  [  0   2 266]]

# %% [markdown]
# ### Random forest

# %%
model_RF = RandomForestClassifier(n_estimators=300, 
                                  max_depth=200, 
                                  min_samples_leaf=1, 
                                  min_samples_split=8, 
                                  class_weight=None,
                                  oob_score=True, 
                                  bootstrap=True)

model_RF.fit(X_train, Bui_train)
Bui_pred_RF = model_RF.predict(X_test)
print(confusion_matrix(Bui_test, Bui_pred_RF, labels=[0, 1, 2]))
Bui_results.loc['RF',:] = compute_classf_metrics(Bui_test, Bui_pred_RF)
print('OOB accuracy=', model_RF.oob_score_)
# Out:
# [[536   0   0]
#  [  1 306   0]
#  [  0   0 268]]
# OOB accuracy= 0.9969403621407433

# %% [markdown]
# ### Extra Trees Classifier

# %%
model_ET = ExtraTreesClassifier(n_estimators=300, 
                                max_depth=200, 
                                min_samples_leaf=1, 
                                min_samples_split=8,
                                class_weight=None,
                                oob_score=True, 
                                bootstrap=True)
model_ET.fit(X_train, Bui_train)
Bui_pred_ET = model_ET.predict(X_test)
print(confusion_matrix(Bui_test, Bui_pred_ET, labels=[0, 1, 2]))
Bui_results.loc['ET',:] = compute_classf_metrics(Bui_test, Bui_pred_ET)
print('OOB accuracy=', model_ET.oob_score_)
# Out:
# [[536   0   0]
#  [  0 307   0]
#  [  0   0 268]]
# OOB accuracy= 0.9978432060992125

# %% [markdown]
# ### k-NN Classifier

# %%
bui_knn = KNeighborsClassifier(n_neighbors=5, 
                               metric='euclidean',
                               weights='distance')

bui_knn.fit(X_train, Bui_train)
Bui_pred_KNN = bui_knn.predict(X_test)
print(confusion_matrix(Bui_test, Bui_pred_KNN, labels=[0, 1, 2]))
Bui_results.loc['KNN',:] = compute_classf_metrics(Bui_test, Bui_pred_KNN)
# Out:
# [[533   2   1]
#  [  0 306   1]
#  [  0   0 268]]

# %% [markdown]
# ### Nearest Centroids Classifier

# %%
Bui_NC = NearestCentroid(metric='chebyshev')

Bui_NC.fit(X_train, Bui_train)
Bui_pred_NC = Bui_NC.predict(X_test)
print(confusion_matrix(Bui_test, Bui_pred_NC, labels=[0, 1, 2]))
Bui_results.loc['NC',:] = compute_classf_metrics(Bui_test, Bui_pred_NC)
# Out:
# [[536   0   0]
#  [  0 305   2]
#  [  0   0 268]]
# c:\users\marcel\.conda\envs\marsu\lib\site-packages\sklearn\neighbors\_nearest_centroid.py:150: UserWarning: Averaging for metrics other than euclidean and manhattan not supported. The average is set to be the mean.
#   warnings.warn("Averaging for metrics other than "

# %% [markdown]
# ## FLOOR Classification

# %% [markdown]
# ### Decision Tree Classifier

# %%
model_tree = DecisionTreeClassifier()

model_tree.fit(X_train, Flo_train)
Flo_pred_DT = model_tree.predict(X_test)
print(confusion_matrix(Flo_test, Flo_pred_DT, labels=[0, 1, 2, 3, 4]))
Flo_results.loc['DT',:] = compute_classf_metrics(Flo_test, Flo_pred_DT)
# Out:
# [[108  14   8   2   0]
#  [ 33 374  50   5   0]
#  [  4  21 255  26   0]
#  [  0   4  24 140   4]
#  [  2   2   0   5  30]]

# %% [markdown]
# ### Random Forest Classifier

# %%
model_rf = RandomForestClassifier(oob_score=True)

model_rf.fit(X_train, Flo_train)
Flo_pred_RF = model_rf.predict(X_test)
print(confusion_matrix(Flo_test, Flo_pred_RF, labels=[0, 1, 2, 3, 4]))
Flo_results.loc['RF',:] = compute_classf_metrics(Flo_test, Flo_pred_RF)
print('OOB accuracy=', model_rf.oob_score_)
# Out:
# [[116   9   7   0   0]
#  [  4 409  48   1   0]
#  [  0   6 292   8   0]
#  [  0   0   5 166   1]
#  [  1   0   0   9  29]]
# OOB accuracy= 0.9951848322214977

# %% [markdown]
# ### Random Forest Classifier 2

# %%
model_rf2 = RandomForestClassifier(n_estimators=300, 
                                   max_depth=200, 
                                   min_samples_leaf=1, 
                                   min_samples_split=8,
                                   class_weight="balanced",
                                   oob_score=True)

model_rf2.fit(X_train, Flo_train)
Flo_pred_RF2 = model_rf2.predict(X_test)
Flo_results.loc['RF-Best',:] = compute_classf_metrics(Flo_test, Flo_pred_RF2)
print(confusion_matrix(Flo_test, Flo_pred_RF2, labels=[0, 1, 2, 3, 4]))
print('OOB accuracy=', model_rf2.oob_score_)
# Out:
# [[116  10   5   1   0]
#  [  5 414  40   3   0]
#  [  0   6 292   8   0]
#  [  0   0   5 166   1]
#  [  1   0   0   9  29]]
# OOB accuracy= 0.9966895721522797

# %% [markdown]
# ### Extra Trees Classifier

# %%
model_et = ExtraTreesClassifier(n_estimators=300, 
                                max_depth=200, 
                                min_samples_leaf=1, 
                                min_samples_split=8, 
                                class_weight='balanced',
                                oob_score=True, 
                                bootstrap=True)

model_et.fit(X_train, Flo_train)
Flo_pred_ET = model_et.predict(X_test)
Flo_results.loc['RF-ET',:] = compute_classf_metrics(Flo_test, Flo_pred_ET)
print(confusion_matrix(Flo_test, Flo_pred_ET, labels=[0, 1, 2, 3, 4]))
print('OOB accuracy=', model_et.oob_score_)
# Out:
# [[116   9   6   1   0]
#  [  7 411  44   0   0]
#  [  0   6 289  11   0]
#  [  0   0   6 165   1]
#  [  1   0   0   6  32]]
# OOB accuracy= 0.9970406781361288

# %% [markdown]
# ### k-NN Classifier

# %%
Flo_knn = KNeighborsClassifier(n_neighbors=5, metric='euclidean',weights='distance')

Flo_knn.fit(X_train, Flo_train)
Flo_pred_KNN = Flo_knn.predict(X_test)
print(confusion_matrix(Flo_test, Flo_pred_KNN, labels=[0, 1, 2, 3, 4]))
Flo_results.loc['KNN-5',:] = compute_classf_metrics(Flo_test, Flo_pred_KNN)
# Out:
# [[120   9   3   0   0]
#  [  9 406  45   2   0]
#  [  1   5 291   9   0]
#  [  0   0   3 168   1]
#  [  2   0   0   4  33]]

# %% [markdown]
# ### Nearest Centroids Classifier

# %%
Flo_NC = NearestCentroid(metric='chebyshev')

Flo_NC.fit(X_train, Flo_train)
Flo_pred_NC=Flo_NC.predict(X_test)
print(confusion_matrix(Flo_test, Flo_pred_NC, labels=[0, 1, 2, 3, 4]))
Flo_results.loc['NC',:] = compute_classf_metrics(Flo_test, Flo_pred_NC)
# Out:
# [[114  16   2   0   0]
#  [ 12 428  18   1   3]
#  [  0  53 238  15   0]
#  [  0   0  13 138  21]
#  [  0   0   0   3  36]]
# c:\users\marcel\.conda\envs\marsu\lib\site-packages\sklearn\neighbors\_nearest_centroid.py:150: UserWarning: Averaging for metrics other than euclidean and manhattan not supported. The average is set to be the mean.
#   warnings.warn("Averaging for metrics other than "

# %%
Bui_results
# Out:
#      Accuracy F1-score (macro avg) Custom error score
# DT   0.971197             0.966974                 42
# RF     0.9991             0.999146                  1
# ET        1.0                  1.0                  0
# KNN    0.9964             0.996199                  5
# NC     0.9982             0.997672                  2

# %%
Flo_results
# Out:
#          Accuracy F1-score (macro avg) Custom error score
# DT       0.816382             0.808435                239
# RF       0.910891              0.90019                110
# RF-Best  0.915392             0.901648                107
# RF-ET    0.911791             0.907651                109
# KNN-5    0.916292             0.915692                105
# NC       0.858686             0.833491                166

# %% [markdown]
# Now we are going to repeat this part but using the PCA-transformed data

# %% [markdown]
# ### BUILDING

# %%
# Decision Tree
model_tree = DecisionTreeClassifier().fit(X_train_pca, Bui_train)
Bui_pred_DT = model_tree.predict(X_test_pca)
#print(confusion_matrix(Bui_test, Bui_pred_DT, labels=[0, 1, 2]))
Bui_results.loc['DT_pca',:] = compute_classf_metrics(Bui_test, Bui_pred_DT)


# Random Forest
model_RF = RandomForestClassifier(n_estimators=300,
                                  max_depth=200, 
                                  min_samples_leaf=1, 
                                  min_samples_split=8, 
                                  class_weight=None,
                                  oob_score=True, bootstrap=True).fit(X_train_pca, Bui_train)
Bui_pred_RF = model_RF.predict(X_test_pca)
#print(confusion_matrix(Bui_test, Bui_pred_RF, labels=[0, 1, 2]))
Bui_results.loc['RF_pca',:] = compute_classf_metrics(Bui_test, Bui_pred_RF)


# Extra Tree
model_ET = ExtraTreesClassifier(n_estimators=300, 
                                max_depth=200, 
                                min_samples_leaf=1, 
                                min_samples_split=8,
                                class_weight=None,oob_score=True, bootstrap=True).fit(X_train_pca, Bui_train)
Bui_pred_ET = model_ET.predict(X_test_pca)
#print(confusion_matrix(Bui_test, Bui_pred_ET, labels=[0, 1, 2]))
Bui_results.loc['ET_pca',:] = compute_classf_metrics(Bui_test, Bui_pred_ET)


# k-NN
bui_knn=KNeighborsClassifier(n_neighbors=5, 
                             metric='euclidean',
                             weights='distance').fit(X_train_pca, Bui_train)
Bui_pred_KNN=bui_knn.predict(X_test_pca)
#print(confusion_matrix(Bui_test, Bui_pred_KNN, labels=[0, 1, 2]))
Bui_results.loc['KNN_pca',:] = compute_classf_metrics(Bui_test, Bui_pred_KNN)

# %% [markdown]
# ### FLOOR

# %%
# Decision Tree
model_tree = DecisionTreeClassifier().fit(X_train_pca, Flo_train)
Flo_pred_DT = model_tree.predict(X_test_pca)
#print(confusion_matrix(Flo_test, Flo_pred_DT, labels=[0, 1, 2, 3, 4]))
Flo_results.loc['DT_pca',:] = compute_classf_metrics(Flo_test, Flo_pred_DT)

# Random Forest
model_rf2 = RandomForestClassifier(n_estimators=300, 
                                   max_depth=200, 
                                   min_samples_leaf=1, 
                                   min_samples_split=8, 
                                   class_weight='balanced',
                                   oob_score=True).fit(X_train_pca, Flo_train)
Flo_pred_RF = model_rf2.predict(X_test_pca)
Flo_results.loc['RF-Best_pca',:] = compute_classf_metrics(Flo_test, Flo_pred_RF)
#print(confusion_matrix(Flo_test, Flo_pred_RF, labels=[0, 1, 2, 3, 4]))

# Extra Trees
model_rf3 = ExtraTreesClassifier(n_estimators=300, 
                                 max_depth=200, 
                                 min_samples_leaf=1, 
                                 min_samples_split=8,
                                 class_weight='balanced',
                                 oob_score=True, 
                                 bootstrap=True).fit(X_train_pca, Flo_train)
Flo_pred_ET = model_rf3.predict(X_test_pca)
Flo_results.loc['RF-ET_pca',:] = compute_classf_metrics(Flo_test, Flo_pred_ET)
#print(confusion_matrix(Flo_test, Flo_pred_ET, labels=[0, 1, 2, 3, 4]))

# k-NN
Flo_knn=KNeighborsClassifier(n_neighbors=5, 
                             metric='euclidean',
                             weights='distance').fit(X_train_pca, Flo_train)
Flo_pred_KNN=Flo_knn.predict(X_test_pca)
#print(confusion_matrix(Flo_test, Flo_pred_KNN, labels=[0, 1, 2, 3, 4]))
Flo_results.loc['KNN-5_pca',:] = compute_classf_metrics(Flo_test, Flo_pred_KNN)

# Multi-Layer Perceptron Classifier
model_nnet = MLPClassifier(hidden_layer_sizes=[4],
                           alpha=0,
                           activation='logistic',
                           max_iter=500,
                           solver='adam',random_state=42)
model_nnet.fit(X_train_pca,Flo_train);
Flo_pred_MLP = model_nnet.predict(X_test_pca)
#print(confusion_matrix(Flo_test,Flo_pred_MLP))
Flo_results.loc['MLP-4-0_pca',:] = compute_classf_metrics(Flo_test, Flo_pred_MLP)

# %%
Bui_results
# Out:
#          Accuracy F1-score (macro avg) Custom error score
# DT       0.971197             0.966974                 42
# RF         0.9991             0.999146                  1
# ET            1.0                  1.0                  0
# KNN        0.9964             0.996199                  5
# NC         0.9982             0.997672                  2
# DT_pca   0.993699             0.993734                  7
# RF_pca     0.9991             0.999147                  1
# ET_pca        1.0                  1.0                  0
# KNN_pca    0.9991             0.998835                  1

# %%
Flo_results
# Out:
#              Accuracy F1-score (macro avg) Custom error score
# DT           0.816382             0.808435                239
# RF           0.910891              0.90019                110
# RF-Best      0.915392             0.901648                107
# RF-ET        0.911791             0.907651                109
# KNN-5        0.916292             0.915692                105
# NC           0.858686             0.833491                166
# DT_pca       0.845185             0.836366                203
# RF-Best_pca  0.932493             0.922921                 90
# RF-ET_pca    0.920792             0.913435                104
# KNN-5_pca    0.917192             0.912582                115
# MLP-4-0_pca  0.886589             0.837437                150

# %% [markdown]
# Finally we are going to try to predict both features together

# %% [markdown]
# ### BUILDING+FLOOR

# %%
train_data["FLOOR"].replace({1: "1", 2: "2", 0 : "0", 3 : "3", 4 : "4"}, inplace=True)
test_data["FLOOR"].replace({1: "1", 2: "2", 0 : "0", 3 : "3", 4 : "4"}, inplace=True)

test_data["BUILDINGID"].replace({1: "1", 2: "2", 0 : "0"}, inplace=True)
train_data["BUILDINGID"].replace({1: "1", 2: "2", 0 : "0"}, inplace=True)

Loc_results = pd.DataFrame(columns=['Accuracy', 'F1-score (macro avg)','Custom error score'])

Loc_train = pd.DataFrame(columns=["Location"])
Loc_train = train_data["BUILDINGID"] + "-" + train_data["FLOOR"]
Loc_test = pd.DataFrame(columns=["Location"])
Loc_test = test_data["BUILDINGID"] + "-" + test_data["FLOOR"]

# %%
def location_error(loc_pred):
    error = 0
    for row in range(len(loc_pred)):
        if (loc_pred[row] != Loc_test[row]):
            (bp,fp)=loc_pred[row].split('-')
            (bt,ft)=Loc_test[row].split('-')
            if (bp != bt):
                error += 10
            if (fp != ft):
                error += abs(int(fp)-int(ft))
    return error

def compute_classf_metrics_loc(y, pred):
    return [accuracy_score(y, pred), f1_score(y, pred, average="macro"), location_error(pred)]

# %%
# Random Forest
model_rf = RandomForestClassifier(n_estimators=300, 
                                  max_depth=200, 
                                  min_samples_leaf=1, 
                                  min_samples_split=8, 
                                  class_weight='balanced',
                                  oob_score=True).fit(X_train, Loc_train)
Loc_pred_RF = model_rf.predict(X_test)
Loc_results.loc['RF-Best',:] = compute_classf_metrics_loc(Loc_test,Loc_pred_RF)
print('OOB accuracy RF =', model_rf.oob_score_)


model_rf_pca = RandomForestClassifier(n_estimators=300, 
                                      max_depth=200, 
                                      min_samples_leaf=1, 
                                      min_samples_split=8, 
                                      class_weight='balanced',oob_score=True).fit(X_train_pca, Loc_train)
Loc_pred_RF_pca = model_rf_pca.predict(X_test_pca)
Loc_results.loc['RF-Best_pca',:] = compute_classf_metrics_loc(Loc_test,Loc_pred_RF_pca)
print('OOB accuracy RF-Best-PCA =', model_rf.oob_score_)


model_rf3 = ExtraTreesClassifier(n_estimators=300, 
                                 max_depth=200, 
                                 min_samples_leaf=1, 
                                 min_samples_split=8,
                                 class_weight='balanced',
                                 oob_score=True, bootstrap=True).fit(X_train_pca, Loc_train)
Loc_pred_ET = model_rf3.predict(X_test_pca)
Loc_results.loc['ET-Best_pca',:] = compute_classf_metrics_loc(Loc_test,Loc_pred_ET)
print('OOB accuracy ET =', model_rf3.oob_score_)


Loc_knn=KNeighborsClassifier(n_neighbors=5, 
                             metric='euclidean',
                             weights='distance').fit(X_train_pca, Loc_train)
Loc_pred_KNN = Loc_knn.predict(X_test_pca)
Loc_results.loc['KNN-Best_pca',:] = compute_classf_metrics_loc(Loc_test,Loc_pred_KNN)
# Out:
# OOB accuracy RF = 0.9966895721522797
# OOB accuracy RF-Best-PCA = 0.9966895721522797
# OOB accuracy ET = 0.9967397301499724

# %%
Loc_results
# Out:
#               Accuracy F1-score (macro avg) Custom error score
# RF-Best       0.911791             0.893807                135
# RF-Best_pca   0.941494             0.928414                 80
# ET-Best_pca   0.925293             0.918426                101
# KNN-Best_pca  0.917192             0.908455                125

# %% [markdown]
# # Regression

# %% [markdown]
# First of all, we are going to scale the data.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

# %%
def compute_metrics(lat_true,lat_pred,lon_true,lon_pred):
    mse_lat = mean_squared_error(lat_true,lat_pred)
    r2_lat = r2_score(lat_true,lat_pred)
    mse_lon = mean_squared_error(lon_true,lon_pred)
    r2_lon = r2_score(lon_true,lon_pred)
    return [mse_lat,r2_lat,mse_lon,r2_lon]

results = pd.DataFrame(columns=['Latitude MSE', 'Latitude R2', 'Longitude MSE', 'Longitude R2'])

# %%
def plot_predictions():
    plt.figure()
    sn.scatterplot(x=pred_lon, y=pred_lat)
    sn.scatterplot(x=lon_test, y=lat_test)
    plt.show()

# %%
# Scaling the data
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train_data.iloc[:,:314])
X = train_scaled[:,0:312]
lon = train_scaled[:,312]
lat = train_scaled[:,313]
latlon = train_scaled[:,312:314]

test_scaled = scaler.transform(test_data.iloc[:,0:314])
X_test = test_scaled[:,:312]
lon_test = test_scaled[:,312]
lat_test = test_scaled[:,313]
latlon_test = test_scaled[:,312:314]

# %% [markdown]
# ## Decision Tree

# %%
tree_reg_lat = DecisionTreeRegressor(random_state=123)
tree_reg_lon = DecisionTreeRegressor(random_state=123)
tree_reg_lat.fit(X, lat)
tree_reg_lon.fit(X, lon)
# Out:
# DecisionTreeRegressor(random_state=123)

# %%
print("Latitude training score:", tree_reg_lat.score(X,lat))
print("Longitude training score:", tree_reg_lon.score(X,lon))
# Out:
# Latitude training score: 0.9964891371361712
# Longitude training score: 0.9976525348376656

# %%
pred_lat = tree_reg_lat.predict(X_test)
pred_lon = tree_reg_lon.predict(X_test)
results.loc['DT-default',:] = compute_metrics(lat_test, pred_lat, lon_test, pred_lon)

# %%
results
# Out:
#            Latitude MSE Latitude R2 Longitude MSE Longitude R2
# DT-default     0.081313    0.926169      0.019434     0.979503

# %%
plot_predictions()

# %% [markdown]
# ### Random Forest

# %%
rfr_lat = RandomForestRegressor(random_state=123)
rfr_lon = RandomForestRegressor(random_state=123)
rfr_lat.fit(X, lat)
rfr_lon.fit(X, lon)
# Out:
# RandomForestRegressor(random_state=123)

# %%
print("Latitude training score:", rfr_lat.score(X,lat))
print("Longitude training score:", rfr_lon.score(X,lon))
# Out:
# Latitude training score: 0.9960426150967083
# Longitude training score: 0.9974166036057185

# %%
pred_lat = rfr_lat.predict(X_test)
pred_lon = rfr_lon.predict(X_test)
results.loc['RF-default',:] = compute_metrics(lat_test, pred_lat,lon_test, pred_lon)

# %%
results
# Out:
#            Latitude MSE Latitude R2 Longitude MSE Longitude R2
# DT-default     0.081313    0.926169      0.019434     0.979503
# RF-default     0.039852    0.963815      0.011751     0.987606

# %%
plot_predictions()

# %% [markdown]
# ### Hyperparameter tunning

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 500, stop = 1000, num = 11)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(50, 150, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [10, 12,15,18,20]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(random_grid)
# Out:
# {'n_estimators': [500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000], 'max_features': ['auto', 'sqrt'], 'max_depth': [50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, None], 'min_samples_split': [10, 12, 15, 18, 20], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
##rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation,
# search across 100 different combinations, and use all available cores
##rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=1, random_state=42, n_jobs = -1)
# Print the best parameters
##rf_random.best_params_

# %%
rf_lat = RandomForestRegressor(n_estimators=850,
                               min_samples_split=10,
                               min_samples_leaf=1,
                               max_features='sqrt',
                               max_depth=130,
                               bootstrap=False,
                               random_state=123)
rf_lon = RandomForestRegressor(n_estimators=850,
                               min_samples_split=10,
                               min_samples_leaf=1,
                               max_features='sqrt',
                               max_depth=130,
                               bootstrap=False,
                               random_state=123)

# %%
rf_lat.fit(X, lat)
rf_lon.fit(X, lon)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=130, max_features='sqrt',
#                       min_samples_split=10, n_estimators=850)

# %%
print("Latitude training score:", rf_lat.score(X,lat))
print("Longitude training score:", rf_lon.score(X,lon))
# Out:
# Latitude training score: 0.9961476683003075
# Longitude training score: 0.9974899400135446

# %%
pred_lat = rf_lat.predict(X_test)
pred_lon = rf_lon.predict(X_test)
results.loc['RF-Best',:] = compute_metrics(lat_test, pred_lat,lon_test, pred_lon)

# %%
results
# Out:
#            Latitude MSE Latitude R2 Longitude MSE Longitude R2
# DT-default     0.081313    0.926169      0.019434     0.979503
# RF-default     0.039852    0.963815      0.011751     0.987606
# RF-Best        0.018856    0.982879      0.006435     0.993213

# %%
plot_predictions()

# %% [markdown]
# ### Neural Networks

# %%
from sklearn.neural_network import MLPRegressor

# %%
nn_lat = MLPRegressor(hidden_layer_sizes=[16,16,16],
                         alpha=1,
                         activation='relu',
                         max_iter=2000,
                         solver='adam',
                         random_state=123,
                         verbose=True,
                         tol=1e-6,
                         early_stopping=True,
                         learning_rate_init=0.0001)
nn_lon = MLPRegressor(hidden_layer_sizes=[16,16,16],
                         alpha=1,
                         activation='relu',
                         max_iter=2000,
                         solver='adam',
                         random_state=123,
                         verbose=True,
                         tol=1e-6,
                         early_stopping=True,
                         learning_rate_init=0.0001)

# %%
nn_lat.fit(X,lat)
nn_lon.fit(X,lon)
# Out:
# Iteration 1, loss = 0.74301220
# Validation score: 0.060364
# Iteration 2, loss = 0.52050896
# Validation score: 0.396933
# Iteration 3, loss = 0.37350137
# Validation score: 0.643860
# Iteration 4, loss = 0.27813550
# Validation score: 0.778941
# Iteration 5, loss = 0.23363799
# Validation score: 0.840006
# Iteration 6, loss = 0.21096276
# Validation score: 0.874836
# Iteration 7, loss = 0.19583966
# Validation score: 0.897427
# Iteration 8, loss = 0.18461593
# Validation score: 0.913606
# Iteration 9, loss = 0.17562252
# Validation score: 0.925223
# Iteration 10, loss = 0.16805719
# Validation score: 0.934109
# Iteration 11, loss = 0.16148150
# Validation score: 0.940766
# Iteration 12, loss = 0.15568695
# Validation score: 0.946130
# Iteration 13, loss = 0.15047696
# Validation score: 0.950230
# Iteration 14, loss = 0.14567568
# Validation score: 0.953670
# Iteration 15, loss = 0.14113314
# Validation score: 0.956550
# Iteration 16, loss = 0.13687211
# Validation score: 0.959159
# Iteration 17, loss = 0.13280803
# Validation score: 0.960932
# Iteration 18, loss = 0.12888056
# Validation score: 0.963040
# Iteration 19, loss = 0.12508042
# Validation score: 0.964700
# Iteration 20, loss = 0.12139146
# Validation score: 0.966131
# Iteration 21, loss = 0.11783932
# Validation score: 0.967344
# Iteration 22, loss = 0.11438528
# Validation score: 0.968493
# Iteration 23, loss = 0.11102850
# Validation score: 0.969513
# Iteration 24, loss = 0.10776166
# Validation score: 0.970440
# Iteration 25, loss = 0.10457649
# Validation score: 0.971177
# Iteration 26, loss = 0.10148396
# Validation score: 0.972139
# Iteration 27, loss = 0.09846364
# Validation score: 0.972760
# Iteration 28, loss = 0.09551576
# Validation score: 0.973606
# Iteration 29, loss = 0.09266547
# Validation score: 0.974235
# Iteration 30, loss = 0.08988410
# Validation score: 0.975001
# Iteration 31, loss = 0.08720514
# Validation score: 0.975527
# Iteration 32, loss = 0.08460148
# Validation score: 0.976060
# Iteration 33, loss = 0.08208133
# Validation score: 0.976541
# Iteration 34, loss = 0.07963360
# Validation score: 0.977227
# Iteration 35, loss = 0.07726809
# Validation score: 0.977596
# Iteration 36, loss = 0.07496335
# Validation score: 0.977951
# Iteration 37, loss = 0.07272901
# Validation score: 0.978465
# Iteration 38, loss = 0.07059517
# Validation score: 0.978844
# Iteration 39, loss = 0.06850623
# Validation score: 0.979076
# Iteration 40, loss = 0.06647847
# Validation score: 0.979431
# Iteration 41, loss = 0.06452174
# Validation score: 0.979773
# Iteration 42, loss = 0.06260904
# Validation score: 0.979860
# Iteration 43, loss = 0.06078402
# Validation score: 0.980308
# Iteration 44, loss = 0.05901331
# Validation score: 0.980599
# Iteration 45, loss = 0.05731550
# Validation score: 0.980814
# Iteration 46, loss = 0.05566547
# Validation score: 0.981023
# Iteration 47, loss = 0.05408314
# Validation score: 0.981188
# Iteration 48, loss = 0.05255875
# Validation score: 0.981544
# Iteration 49, loss = 0.05108765
# Validation score: 0.981564
# Iteration 50, loss = 0.04968948
# Validation score: 0.981673
# Iteration 51, loss = 0.04831931
# Validation score: 0.981592
# Iteration 52, loss = 0.04701733
# Validation score: 0.981842
# Iteration 53, loss = 0.04576087
# Validation score: 0.981809
# Iteration 54, loss = 0.04455342
# Validation score: 0.982218
# Iteration 55, loss = 0.04336880
# Validation score: 0.982151
# Iteration 56, loss = 0.04225823
# Validation score: 0.982330
# Iteration 57, loss = 0.04117689
# Validation score: 0.982442
# Iteration 58, loss = 0.04014703
# Validation score: 0.982453
# Iteration 59, loss = 0.03916383
# Validation score: 0.982427
# Iteration 60, loss = 0.03821970
# Validation score: 0.982553
# Iteration 61, loss = 0.03731930
# Validation score: 0.982680
# Iteration 62, loss = 0.03643417
# Validation score: 0.982586
# Iteration 63, loss = 0.03560141
# Validation score: 0.982821
# Iteration 64, loss = 0.03480944
# Validation score: 0.982630
# Iteration 65, loss = 0.03405301
# Validation score: 0.982785
# Iteration 66, loss = 0.03331690
# Validation score: 0.982731
# Iteration 67, loss = 0.03262822
# Validation score: 0.982901
# Iteration 68, loss = 0.03198105
# Validation score: 0.982803
# Iteration 69, loss = 0.03133313
# Validation score: 0.982973
# Iteration 70, loss = 0.03073839
# Validation score: 0.982882
# Iteration 71, loss = 0.03015668
# Validation score: 0.982836
# Iteration 72, loss = 0.02960015
# Validation score: 0.983018
# Iteration 73, loss = 0.02907881
# Validation score: 0.983042
# Iteration 74, loss = 0.02856746
# Validation score: 0.983049
# Iteration 75, loss = 0.02808263
# Validation score: 0.983143
# Iteration 76, loss = 0.02761891
# Validation score: 0.982960
# Iteration 77, loss = 0.02719290
# Validation score: 0.983322
# Iteration 78, loss = 0.02674899
# Validation score: 0.983123
# Iteration 79, loss = 0.02636944
# Validation score: 0.983155
# Iteration 80, loss = 0.02599153
# Validation score: 0.982961
# Iteration 81, loss = 0.02562477
# Validation score: 0.983141
# Iteration 82, loss = 0.02528571
# Validation score: 0.983277
# Iteration 83, loss = 0.02496102
# Validation score: 0.983035
# Iteration 84, loss = 0.02467135
# Validation score: 0.983230
# Iteration 85, loss = 0.02435497
# Validation score: 0.983078
# Iteration 86, loss = 0.02407166
# Validation score: 0.983348
# Iteration 87, loss = 0.02380876
# Validation score: 0.983261
# Iteration 88, loss = 0.02355629
# Validation score: 0.983415
# Iteration 89, loss = 0.02332045
# Validation score: 0.983067
# Iteration 90, loss = 0.02309743
# Validation score: 0.983412
# Iteration 91, loss = 0.02286680
# Validation score: 0.983324
# Iteration 92, loss = 0.02266462
# Validation score: 0.983471
# Iteration 93, loss = 0.02247053
# Validation score: 0.983298
# Iteration 94, loss = 0.02227530
# Validation score: 0.983410
# Iteration 95, loss = 0.02209077
# Validation score: 0.983507
# Iteration 96, loss = 0.02190902
# Validation score: 0.983408
# Iteration 97, loss = 0.02175214
# Validation score: 0.983497
# Iteration 98, loss = 0.02160336
# Validation score: 0.983523
# Iteration 99, loss = 0.02145920
# Validation score: 0.983324
# Iteration 100, loss = 0.02132525
# Validation score: 0.983416
# Iteration 101, loss = 0.02118480
# Validation score: 0.983503
# Iteration 102, loss = 0.02105694
# Validation score: 0.983442
# Iteration 103, loss = 0.02093890
# Validation score: 0.983656
# Iteration 104, loss = 0.02080869
# Validation score: 0.983575
# Iteration 105, loss = 0.02070952
# Validation score: 0.983430
# Iteration 106, loss = 0.02058087
# Validation score: 0.983640
# Iteration 107, loss = 0.02046741
# Validation score: 0.983780
# Iteration 108, loss = 0.02036849
# Validation score: 0.983580
# Iteration 109, loss = 0.02027632
# Validation score: 0.983734
# Iteration 110, loss = 0.02017772
# Validation score: 0.983880
# Iteration 111, loss = 0.02009039
# Validation score: 0.983562
# Iteration 112, loss = 0.02001750
# Validation score: 0.983726
# Iteration 113, loss = 0.01993747
# Validation score: 0.983714
# Iteration 114, loss = 0.01986540
# Validation score: 0.983684
# Iteration 115, loss = 0.01978826
# Validation score: 0.983846
# Iteration 116, loss = 0.01973601
# Validation score: 0.983668
# Iteration 117, loss = 0.01965619
# Validation score: 0.983709
# Iteration 118, loss = 0.01961130
# Validation score: 0.983574
# Iteration 119, loss = 0.01953750
# Validation score: 0.983677
# Iteration 120, loss = 0.01950977
# Validation score: 0.983863
# Iteration 121, loss = 0.01944496
# Validation score: 0.983790
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.83057592
# Validation score: -0.086113
# Iteration 2, loss = 0.61149234
# Validation score: 0.236036
# Iteration 3, loss = 0.45640997
# Validation score: 0.531182
# Iteration 4, loss = 0.31899905
# Validation score: 0.754378
# Iteration 5, loss = 0.24238470
# Validation score: 0.836648
# Iteration 6, loss = 0.21577580
# Validation score: 0.870372
# Iteration 7, loss = 0.19974318
# Validation score: 0.893393
# Iteration 8, loss = 0.18742075
# Validation score: 0.910176
# Iteration 9, loss = 0.17761750
# Validation score: 0.923238
# Iteration 10, loss = 0.16939229
# Validation score: 0.933169
# Iteration 11, loss = 0.16246656
# Validation score: 0.940713
# Iteration 12, loss = 0.15637526
# Validation score: 0.947029
# Iteration 13, loss = 0.15089503
# Validation score: 0.952174
# Iteration 14, loss = 0.14583916
# Validation score: 0.956559
# Iteration 15, loss = 0.14115613
# Validation score: 0.960229
# Iteration 16, loss = 0.13665173
# Validation score: 0.963526
# Iteration 17, loss = 0.13237435
# Validation score: 0.966264
# Iteration 18, loss = 0.12827973
# Validation score: 0.968578
# Iteration 19, loss = 0.12441920
# Validation score: 0.970583
# Iteration 20, loss = 0.12076867
# Validation score: 0.972223
# Iteration 21, loss = 0.11728830
# Validation score: 0.973772
# Iteration 22, loss = 0.11394465
# Validation score: 0.975113
# Iteration 23, loss = 0.11072121
# Validation score: 0.976316
# Iteration 24, loss = 0.10759749
# Validation score: 0.977379
# Iteration 25, loss = 0.10455501
# Validation score: 0.978360
# Iteration 26, loss = 0.10160522
# Validation score: 0.979238
# Iteration 27, loss = 0.09871955
# Validation score: 0.980027
# Iteration 28, loss = 0.09593343
# Validation score: 0.980797
# Iteration 29, loss = 0.09320707
# Validation score: 0.981416
# Iteration 30, loss = 0.09055187
# Validation score: 0.982044
# Iteration 31, loss = 0.08796188
# Validation score: 0.982538
# Iteration 32, loss = 0.08542495
# Validation score: 0.982989
# Iteration 33, loss = 0.08294877
# Validation score: 0.983462
# Iteration 34, loss = 0.08054199
# Validation score: 0.983892
# Iteration 35, loss = 0.07818692
# Validation score: 0.984266
# Iteration 36, loss = 0.07590290
# Validation score: 0.984503
# Iteration 37, loss = 0.07365943
# Validation score: 0.984926
# Iteration 38, loss = 0.07148025
# Validation score: 0.985269
# Iteration 39, loss = 0.06935661
# Validation score: 0.985549
# Iteration 40, loss = 0.06725983
# Validation score: 0.985864
# Iteration 41, loss = 0.06524203
# Validation score: 0.986153
# Iteration 42, loss = 0.06325457
# Validation score: 0.986331
# Iteration 43, loss = 0.06132119
# Validation score: 0.986623
# Iteration 44, loss = 0.05945255
# Validation score: 0.986858
# Iteration 45, loss = 0.05762446
# Validation score: 0.987058
# Iteration 46, loss = 0.05583937
# Validation score: 0.987280
# Iteration 47, loss = 0.05410603
# Validation score: 0.987428
# Iteration 48, loss = 0.05243185
# Validation score: 0.987619
# Iteration 49, loss = 0.05079897
# Validation score: 0.987678
# Iteration 50, loss = 0.04921099
# Validation score: 0.987816
# Iteration 51, loss = 0.04769077
# Validation score: 0.987929
# Iteration 52, loss = 0.04619747
# Validation score: 0.988026
# Iteration 53, loss = 0.04476000
# Validation score: 0.988120
# Iteration 54, loss = 0.04336202
# Validation score: 0.988328
# Iteration 55, loss = 0.04201385
# Validation score: 0.988394
# Iteration 56, loss = 0.04070934
# Validation score: 0.988509
# Iteration 57, loss = 0.03946098
# Validation score: 0.988578
# Iteration 58, loss = 0.03825896
# Validation score: 0.988620
# Iteration 59, loss = 0.03710419
# Validation score: 0.988677
# Iteration 60, loss = 0.03600056
# Validation score: 0.988720
# Iteration 61, loss = 0.03493205
# Validation score: 0.988756
# Iteration 62, loss = 0.03391546
# Validation score: 0.988785
# Iteration 63, loss = 0.03293369
# Validation score: 0.988867
# Iteration 64, loss = 0.03200980
# Validation score: 0.988790
# Iteration 65, loss = 0.03110844
# Validation score: 0.988830
# Iteration 66, loss = 0.03022936
# Validation score: 0.988832
# Iteration 67, loss = 0.02939925
# Validation score: 0.988844
# Iteration 68, loss = 0.02860049
# Validation score: 0.988850
# Iteration 69, loss = 0.02783225
# Validation score: 0.988891
# Iteration 70, loss = 0.02710293
# Validation score: 0.988838
# Iteration 71, loss = 0.02639229
# Validation score: 0.988870
# Iteration 72, loss = 0.02572813
# Validation score: 0.988852
# Iteration 73, loss = 0.02508042
# Validation score: 0.988936
# Iteration 74, loss = 0.02447314
# Validation score: 0.988935
# Iteration 75, loss = 0.02389472
# Validation score: 0.988909
# Iteration 76, loss = 0.02333607
# Validation score: 0.988963
# Iteration 77, loss = 0.02280837
# Validation score: 0.988940
# Iteration 78, loss = 0.02230704
# Validation score: 0.989014
# Iteration 79, loss = 0.02183559
# Validation score: 0.988931
# Iteration 80, loss = 0.02136749
# Validation score: 0.988813
# Iteration 81, loss = 0.02096452
# Validation score: 0.988820
# Iteration 82, loss = 0.02055143
# Validation score: 0.989004
# Iteration 83, loss = 0.02014499
# Validation score: 0.988946
# Iteration 84, loss = 0.01978872
# Validation score: 0.988975
# Iteration 85, loss = 0.01943563
# Validation score: 0.988966
# Iteration 86, loss = 0.01910627
# Validation score: 0.988953
# Iteration 87, loss = 0.01879684
# Validation score: 0.989050
# Iteration 88, loss = 0.01850805
# Validation score: 0.989033
# Iteration 89, loss = 0.01823620
# Validation score: 0.988990
# Iteration 90, loss = 0.01797371
# Validation score: 0.989078
# Iteration 91, loss = 0.01772199
# Validation score: 0.989095
# Iteration 92, loss = 0.01749468
# Validation score: 0.989058
# Iteration 93, loss = 0.01728568
# Validation score: 0.988936
# Iteration 94, loss = 0.01709048
# Validation score: 0.989083
# Iteration 95, loss = 0.01689282
# Validation score: 0.989036
# Iteration 96, loss = 0.01671403
# Validation score: 0.989159
# Iteration 97, loss = 0.01656908
# Validation score: 0.989095
# Iteration 98, loss = 0.01639166
# Validation score: 0.989124
# Iteration 99, loss = 0.01625065
# Validation score: 0.989087
# Iteration 100, loss = 0.01611446
# Validation score: 0.989079
# Iteration 101, loss = 0.01599257
# Validation score: 0.989112
# Iteration 102, loss = 0.01587416
# Validation score: 0.989225
# Iteration 103, loss = 0.01576466
# Validation score: 0.989226
# Iteration 104, loss = 0.01566330
# Validation score: 0.989166
# Iteration 105, loss = 0.01556814
# Validation score: 0.989131
# Iteration 106, loss = 0.01547756
# Validation score: 0.989167
# Iteration 107, loss = 0.01539343
# Validation score: 0.989279
# Iteration 108, loss = 0.01531560
# Validation score: 0.989192
# Iteration 109, loss = 0.01525186
# Validation score: 0.989222
# Iteration 110, loss = 0.01519599
# Validation score: 0.989269
# Iteration 111, loss = 0.01512527
# Validation score: 0.989212
# Iteration 112, loss = 0.01507062
# Validation score: 0.989291
# Iteration 113, loss = 0.01501582
# Validation score: 0.989150
# Iteration 114, loss = 0.01495833
# Validation score: 0.989301
# Iteration 115, loss = 0.01491628
# Validation score: 0.989311
# Iteration 116, loss = 0.01487797
# Validation score: 0.989313
# Iteration 117, loss = 0.01483550
# Validation score: 0.989245
# Iteration 118, loss = 0.01478981
# Validation score: 0.989168
# Iteration 119, loss = 0.01476479
# Validation score: 0.989298
# Iteration 120, loss = 0.01474063
# Validation score: 0.989210
# Iteration 121, loss = 0.01470884
# Validation score: 0.989320
# Iteration 122, loss = 0.01467178
# Validation score: 0.989283
# Iteration 123, loss = 0.01465444
# Validation score: 0.989228
# Iteration 124, loss = 0.01463822
# Validation score: 0.989313
# Iteration 125, loss = 0.01460660
# Validation score: 0.989316
# Iteration 126, loss = 0.01458847
# Validation score: 0.989303
# Iteration 127, loss = 0.01456275
# Validation score: 0.989275
# Iteration 128, loss = 0.01454135
# Validation score: 0.989264
# Iteration 129, loss = 0.01451993
# Validation score: 0.989223
# Iteration 130, loss = 0.01451018
# Validation score: 0.989314
# Iteration 131, loss = 0.01448170
# Validation score: 0.989266
# Iteration 132, loss = 0.01447484
# Validation score: 0.989312
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# MLPRegressor(alpha=1, early_stopping=True, hidden_layer_sizes=[16, 16, 16],
#              learning_rate_init=0.0001, max_iter=2000, random_state=123,
#              tol=1e-06, verbose=True)

# %%
print("Latitude training score:", nn_lat.score(X,lat))
print("Longitude training score:", nn_lon.score(X,lon))
# Out:
# Latitude training score: 0.9867901138075028
# Longitude training score: 0.9914123545383635

# %%
pred_lat = nn_lat.predict(X_test)
pred_lon = nn_lon.predict(X_test)
results.loc['NN',:] = compute_metrics(lat_test, pred_lat, lon_test, pred_lon)

# %%
results
# Out:
#            Latitude MSE Latitude R2 Longitude MSE Longitude R2
# DT-default     0.081313    0.926169      0.019434     0.979503
# RF-default     0.039852    0.963815      0.011751     0.987606
# RF-Best        0.018856    0.982879      0.006435     0.993213
# NN              0.07055    0.935942      0.033436     0.964734

# %%
plot_predictions()
